# %%
from bs4 import BeautifulSoup
import io, os.path
import requests
import re

# %% [markdown]
# `pip install beautifulsoup4`

# %% [markdown]
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
html_doc = """
<html><head><title><img atrybut="wartosc">tresc</img>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
soup
# Out:
# <html><head><title><img atrybut="wartosc"/>trescThe Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    <img atrybut="wartosc"/>
#    trescThe Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# # Szukanie pierwszego znacznika z brzegu

# %%
soup.title
# Out:
# <title><img atrybut="wartosc"/>trescThe Dormouse's story</title>

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %% [markdown]
# # Co można zrobić ze znacznikiem?

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.contents
# Out:
# [<img atrybut="wartosc"/>, "trescThe Dormouse's story"]

# %%
soup.html.contents
# Out:
# [<head><title><img atrybut="wartosc"/>trescThe Dormouse's story</title></head>,
#  '\n',
#  <body>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body>]

# %%
soup.title.string

# %%
soup.title.text
# Out:
# "trescThe Dormouse's story"

# %%
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.p["class"] # wyjąte, w calass dostajemy listę
# Out:
# ['title']

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.a["href"] # wszędzie indziej dostajemy napis
# Out:
# 'http://example.com/elsie'

# %%
type(soup.a.attrs)
# Out:
# dict

# %%
soup.a.attrs
# Out:
# {'href': 'http://example.com/elsie', 'class': ['sister'], 'id': 'link1'}

# %% [markdown]
# # Szukanie znacznika

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all("a")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="" id="link3">Tillie</a>]

# %%
soup.find_all(href="http://example.com/elsie")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %%
soup.find_all("a", href="http://example.com/elsie")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %%
# Ture oznacza że dany wskaźnik istnieje
soup.find_all(id=True)
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="" id="link3">Tillie</a>]

# %%
soup.find_all(class_="sister")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="" id="link3">Tillie</a>]

# %%
soup.find_all("a", href="http://example.com/elsie", id=True, class_="sister")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %%
tytul = soup.title

# %%
tytul.find_all("a")
# Out:
# []

# %%
body = soup.body

# %%
for i in body.find_all("a"):
    print(i.attrs)
# Out:
# {'href': 'http://example.com/elsie', 'class': ['sister'], 'id': 'link1'}
# {'href': 'http://example.com/lacie', 'class': ['sister'], 'id': 'link2'}
# {'href': '', 'class': ['sister'], 'id': 'link3'}

# %%
soup.find_all("img")
# Out:
# [<img atrybut="wartosc"/>]

# %% [markdown]
# # next_sibling, previous_sibling (chodzimy po jednym poziomie drzewa parsowania)

# %%
head = soup.head

# %%
head.next_sibling.next_sibling
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>

# %%
head.next_sibling.previous_sibling
# Out:
# <head><title><img atrybut="wartosc"/>trescThe Dormouse's story</title></head>

# %%
head.next_sibling.next_sibling.next_sibling

# %% [markdown]
# # next_element, previous_element (chodzimy po kolejnych elementach w kodzie)

# %%
head
# Out:
# <head><title><img atrybut="wartosc"/>trescThe Dormouse's story</title></head>

# %%
head.next_element
# Out:
# <title><img atrybut="wartosc"/>trescThe Dormouse's story</title>

# %%
head.next_element.next_element.next_element.next_element.next_element
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>

# %% [markdown]
# # Dla ulubionej strony (sugeruję jakiś artykuł na Wiki) znajdź wszystkie linki

# %% [markdown]
# * dla linka `<a atrybut1="asd" href="strona" atrybut2="dsa">Opis</a>` chcemy wydobyć "strona" i "Opis"

# %% [markdown]
# https://pl.wikipedia.org/wiki/Zygmunt_III_Waza

# %%
www = requests.get("https://pl.wikipedia.org/wiki/Zygmunt_III_Waza")

# %%
www.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="pl" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Zygmunt III Waza – Wikipedia, wolna encyklopedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","styczeń","luty","marzec","kwiecień","maj","czerwiec","lipiec","sierpień","wrzesień","październik","listopad","grudzień"],"wgRequestId":"44941651-7e8f-48a9-9426-b054630ba7ae","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Zygmunt_III_Waza","wgTitle":"Zygmunt III Waza","wgCurRevisionId":60801356,"wgRevisionId":60801356,"wgArticleId":31966,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Właściwość P569 inna niż wpisana lokalnie","Właściwość P119 inna niż wpisana lokalnie","Biografie kanonu polskiej Wikipedii","Zygmunt III Waza","Władcy Polski","Władcy elekcyjni I Rzeczypospolitej","Władcy Litwy","Władcy Szwecji",\n"Fundatorzy obiektów sakralnych I Rzeczypospolitej","Polscy działacze kontrreformacji","Polacy odznaczeni Orderem Złotego Runa","Uczestnicy wojny polsko-rosyjskiej 1609–1618 (strona polska)","Uczestnicy wojny polsko-szwedzkiej 1626–1629 (strona polska)","Wazowie","Pochowani w bazylice archikatedralnej św. Stanisława i św. Wacława w Krakowie","Urodzeni w 1566","Władcy Polski koronowani w katedrze wawelskiej","Zmarli w 1632","Władcy Finlandii"],"wgPageContentLanguage":"pl","wgPageContentModel":"wikitext","wgRelevantPageName":"Zygmunt_III_Waza","wgRelevantArticleId":31966,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"accuracy":{"levels":1,"quality":2,"pristine":4}}},"wgStableRevisionId":60801356,"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"pl",\n"pageLanguageDir":"ltr","pageVariantFallbacks":"pl"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!0},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"polski","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q52940"};RLSTATE={"ext.gadget.small-references":"ready","ext.gadget.citation-access-info":"ready","ext.gadget.main-page-css":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.flaggedRevs.icons":"ready","oojs-ui-core.styles":"ready","oojs-ui.styles.indicators":"ready","mediawiki.widgets.styles":"ready","oojs-ui-core.icons":"ready","ext.cite.styles":"ready","mediawiki.page.gallery.styles":"ready","skins.vector.styles.legacy":"ready","mediawiki.toc.styles":"ready",\n"ext.flaggedRevs.basic":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","ext.scribunto.logs","site","mediawiki.page.ready","mediawiki.toc","skins.vector.legacy.js","ext.flaggedRevs.advanced","ext.gadget.ll-script-loader","ext.gadget.maps","ext.gadget.heading-icons","ext.gadget.refToolbar","ext.gadget.edit-buttons","ext.gadget.edit-summaries","ext.gadget.edit-first-section","ext.gadget.edit-summary-warning","ext.gadget.wikibugs","ext.gadget.nuxTBKeys","ext.gadget.enhanced-upload","ext.gadget.map-toggler","ext.gadget.ReferenceTooltips","ext.gadget.narrowFootnoteColumns","ext.gadget.WDsearch","ext.gadget.main-page-js","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ex ...

# %% [markdown]
# # Linki względne

# %% [markdown]
# Bierzemy "korzeń" https://pl.wikipedia.org i doklejamy do niego link względny: /wiki/Wikipedia:Wersje_przejrzane, co daje nam w wyniku https://pl.wikipedia.org/wiki/Wikipedia:Wersje_przejrzane. Dzięki temu nie trzeba zmieniać linków jak zmieni się domena (rebranding, kwestie polityczne, finansowe)

# %% [markdown]
# * https://pl.wikipedia.org/wiki/Zygmunt_III_Waza
# * /wiki/Plik:Sigismundus_III_Rex_-_signature.png
# * https://pl.wikipedia.org/wiki/Plik:Sigismundus_III_Rex_-_signature.png

# %% [markdown]
# # Filmweb

# %% [markdown]
# https://www.filmweb.pl/film/Zenek-2020-829225

# %% [markdown]
# * reżyser
# * data premiery (przekonwertować do daty rozumianej przez Python/Pandas)
# * gatunek (lista)
# * ocena (jako `float`) (najtrudniejsze, na koniec)

# %% [markdown]
# W terminalu:
#
# ```
# conda config --add channels conda-forge
# conda install dateparser
# ```

# %% [markdown]
# ## Reżyseria

# %% [markdown]
# ## Data premiery

# %% [markdown]
# ## Gatunki

# %% [markdown]
# ## Ocena

# %% [markdown]
# # Jak uzyskać URL do Filmwebu mając tytuł filmu?

# %% [markdown]
# * Wejść na stronę https://www.filmweb.pl/search?q=Zenek
# * Zescrapować pierwszy wynik (jego url)

# %% [markdown]
# # Scrapowanie Tabel w Pandasie

# %% [markdown]
# https://www.boxofficemojo.com/year/?ref_=bo_nb_hm_secondarytab

# %% [markdown]
# # Złośliwe strony, przedstawianie się jako przeglądarka

# %% [markdown]
# https://www.metacritic.com/game/pc/warcraft-iii-reforged
