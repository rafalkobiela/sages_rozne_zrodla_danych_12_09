# %%
import pandas as pd
import numpy as np
import sqlite3
import os

# %%
airlines = pd.read_csv("nycflights13_airlines.csv.gz", comment="#")
airports = pd.read_csv("nycflights13_airports.csv.gz", comment="#")
flights = pd.read_csv("nycflights13_flights.csv.gz", comment="#")
planes = pd.read_csv("nycflights13_planes.csv.gz", comment="#")
weather = pd.read_csv("nycflights13_weather.csv.gz", comment="#")

# %% [markdown]
# Baza danych to plik (w naszym przypadku), i baza danych to zbiór tabel.

# %%
db_name = 'nycflights.db'
con = sqlite3.connect(db_name) # tworzenie lub łączenie się z bazą danych

airlines.to_sql("airlines", con, if_exists='replace', index=False) # wrzucanie tabel do bazy danych
airports.to_sql("airports", con, if_exists='replace', index=False)
flights.to_sql("flights", con, if_exists='replace', index=False)
planes.to_sql("planes", con, if_exists='replace', index=False)
weather.to_sql("weather", con, if_exists='replace', index=False)

# %% [markdown]
# # Wybór kolumn

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes", con)
sql_result
# Out:
#      tailnum    year                     type                   manufacturer  \
# 0     N10156  2004.0  Fixed wing multi engine                        EMBRAER
# 1     N102UW  1998.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 2     N103US  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 3     N104UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 4     N10575  2002.0  Fixed wing multi engine                        EMBRAER
# ...      ...     ...                      ...                            ...
# 3317  N997AT  2002.0  Fixed wing multi engine                         BOEING
# 3318  N997DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 3319  N998AT  2002.0  Fixed wing multi engine                         BOEING
# 3320  N998DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 3321  N999DN  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
#
#           model  engines  seats  speed     engine
# 0     EMB-145XR        2     55    NaN  Turbo-fan
# 1      A320-214        2    182    NaN  Turbo-fan
# 2      A320-214        2    182    NaN  Turbo-fan
# 3      A320-214        2    182    NaN  Turbo-fan
# 4     EMB-145LR        2     55    NaN  Turbo-fan
# ...         ...      ...    ...    ...        ...
# 3317    717-200        2    100    NaN  Turbo-fan
# 3318      MD-88        2    142    NaN  Turbo-fan
# 3319    717-200        2    100    NaN  Turbo-fan
# 3320      MD-88        2    142    NaN  Turbo-jet
# 3321      MD-88        2    142    NaN  Turbo-jet
#
# [3322 rows x 9 columns]

# %%
sql_result = pd.read_sql_query("SELECT type, model FROM planes", con)
sql_result
# Out:
#                          type      model
# 0     Fixed wing multi engine  EMB-145XR
# 1     Fixed wing multi engine   A320-214
# 2     Fixed wing multi engine   A320-214
# 3     Fixed wing multi engine   A320-214
# 4     Fixed wing multi engine  EMB-145LR
# ...                       ...        ...
# 3317  Fixed wing multi engine    717-200
# 3318  Fixed wing multi engine      MD-88
# 3319  Fixed wing multi engine    717-200
# 3320  Fixed wing multi engine      MD-88
# 3321  Fixed wing multi engine      MD-88
#
# [3322 rows x 2 columns]

# %%
sql_result = pd.read_sql_query("SELECT model, type FROM planes", con)
sql_result
# Out:
#           model                     type
# 0     EMB-145XR  Fixed wing multi engine
# 1      A320-214  Fixed wing multi engine
# 2      A320-214  Fixed wing multi engine
# 3      A320-214  Fixed wing multi engine
# 4     EMB-145LR  Fixed wing multi engine
# ...         ...                      ...
# 3317    717-200  Fixed wing multi engine
# 3318      MD-88  Fixed wing multi engine
# 3319    717-200  Fixed wing multi engine
# 3320      MD-88  Fixed wing multi engine
# 3321      MD-88  Fixed wing multi engine
#
# [3322 rows x 2 columns]

# %%
# można dospecyfikować, z której tabeli chcemy wziąć kolumnę
# ma sens, gdy w zapytaniu jest więcej tabel i nazwy kolumn się powtarzają
sql_result = pd.read_sql_query("SELECT planes.model, planes.type FROM planes", con)
sql_result
# Out:
#           model                     type
# 0     EMB-145XR  Fixed wing multi engine
# 1      A320-214  Fixed wing multi engine
# 2      A320-214  Fixed wing multi engine
# 3      A320-214  Fixed wing multi engine
# 4     EMB-145LR  Fixed wing multi engine
# ...         ...                      ...
# 3317    717-200  Fixed wing multi engine
# 3318      MD-88  Fixed wing multi engine
# 3319    717-200  Fixed wing multi engine
# 3320      MD-88  Fixed wing multi engine
# 3321      MD-88  Fixed wing multi engine
#
# [3322 rows x 2 columns]

# %% [markdown]
# ### Aliasy

# %%
# aliasy na kolumny
sql_result = pd.read_sql_query("SELECT planes.model as modelik, planes.type as typik FROM planes", con)
sql_result
# Out:
#         modelik                    typik
# 0     EMB-145XR  Fixed wing multi engine
# 1      A320-214  Fixed wing multi engine
# 2      A320-214  Fixed wing multi engine
# 3      A320-214  Fixed wing multi engine
# 4     EMB-145LR  Fixed wing multi engine
# ...         ...                      ...
# 3317    717-200  Fixed wing multi engine
# 3318      MD-88  Fixed wing multi engine
# 3319    717-200  Fixed wing multi engine
# 3320      MD-88  Fixed wing multi engine
# 3321      MD-88  Fixed wing multi engine
#
# [3322 rows x 2 columns]

# %%
# alias na tabele
# nie mozna uzyc oryginalnej nazwy
sql_result = pd.read_sql_query("SELECT p.model, p.type FROM planes as p", con)
sql_result
# Out:
#           model                     type
# 0     EMB-145XR  Fixed wing multi engine
# 1      A320-214  Fixed wing multi engine
# 2      A320-214  Fixed wing multi engine
# 3      A320-214  Fixed wing multi engine
# 4     EMB-145LR  Fixed wing multi engine
# ...         ...                      ...
# 3317    717-200  Fixed wing multi engine
# 3318      MD-88  Fixed wing multi engine
# 3319    717-200  Fixed wing multi engine
# 3320      MD-88  Fixed wing multi engine
# 3321      MD-88  Fixed wing multi engine
#
# [3322 rows x 2 columns]

# %% [markdown]
# ### LIMIT

# %%
# Limit to odpowiednik head() z Pandasa
# w innych silnikach czasem "top"
sql_result = pd.read_sql_query("SELECT p.model as modelik, p.type as typek FROM planes as p LIMIT 5", con)
sql_result
# Out:
#      modelik                    typek
# 0  EMB-145XR  Fixed wing multi engine
# 1   A320-214  Fixed wing multi engine
# 2   A320-214  Fixed wing multi engine
# 3   A320-214  Fixed wing multi engine
# 4  EMB-145LR  Fixed wing multi engine

# %% [markdown]
# ### Dygresja: łamanie zapytania

# %%
# napis wielolinijkowy
sql_result = pd.read_sql_query("""
SELECT p.model as modelik, p.type as typek 
FROM planes as p 
LIMIT 5
""", con)
sql_result
# Out:
#      modelik                    typek
# 0  EMB-145XR  Fixed wing multi engine
# 1   A320-214  Fixed wing multi engine
# 2   A320-214  Fixed wing multi engine
# 3   A320-214  Fixed wing multi engine
# 4  EMB-145LR  Fixed wing multi engine

# %%
# mniej wygodnie, z łamaniem wierszy
sql_result = pd.read_sql_query(
"SELECT p.model as modelik, p.type as typek \
FROM planes as p \
LIMIT 5",
con)
sql_result
# Out:
#      modelik                    typek
# 0  EMB-145XR  Fixed wing multi engine
# 1   A320-214  Fixed wing multi engine
# 2   A320-214  Fixed wing multi engine
# 3   A320-214  Fixed wing multi engine
# 4  EMB-145LR  Fixed wing multi engine

# %% [markdown]
# # Where

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE year >= 2012", con)
sql_result
# Out:
#     tailnum    year                     type      manufacturer     model  \
# 0    N150UW  2013.0  Fixed wing multi engine            AIRBUS  A321-211
# 1    N151UW  2013.0  Fixed wing multi engine            AIRBUS  A321-211
# 2    N152UW  2013.0  Fixed wing multi engine            AIRBUS  A321-211
# 3    N153UW  2013.0  Fixed wing multi engine            AIRBUS  A321-211
# 4    N154UW  2013.0  Fixed wing multi engine            AIRBUS  A321-211
# ..      ...     ...                      ...               ...       ...
# 182  N8620H  2013.0  Fixed wing multi engine            BOEING   737-8H4
# 183  N8621A  2013.0  Fixed wing multi engine            BOEING   737-8H4
# 184  N903JB  2013.0  Fixed wing multi engine            AIRBUS  A321-231
# 185  N907JB  2013.0  Fixed wing multi engine  AIRBUS INDUSTRIE  A321-231
# 186  N913JB  2013.0  Fixed wing multi engine            AIRBUS  A321-231
#
#      engines  seats speed     engine
# 0          2    199  None  Turbo-fan
# 1          2    199  None  Turbo-fan
# 2          2    199  None  Turbo-fan
# 3          2    199  None  Turbo-fan
# 4          2    199  None  Turbo-fan
# ..       ...    ...   ...        ...
# 182        2    140  None  Turbo-fan
# 183        2    140  None  Turbo-fan
# 184        2    379  None  Turbo-fan
# 185        2    379  None  Turbo-fan
# 186        2    379  None  Turbo-fan
#
# [187 rows x 9 columns]

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE year = 2012", con)
sql_result
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 0   N20904  2012.0  Fixed wing multi engine       BOEING      787-8        2
# 1   N26906  2012.0  Fixed wing multi engine       BOEING      787-8        2
# 2   N27901  2012.0  Fixed wing multi engine       BOEING      787-8        2
# 3   N28457  2012.0  Fixed wing multi engine       BOEING  737-924ER        2
# 4   N34455  2012.0  Fixed wing multi engine       BOEING  737-924ER        2
# ..     ...     ...                      ...          ...        ...      ...
# 90  N8601C  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 91  N8602F  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 92  N8603F  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 93  N8604K  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 94  N8605E  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
#
#     seats speed     engine
# 0     260  None  Turbo-fan
# 1     260  None  Turbo-fan
# 2     260  None  Turbo-fan
# 3     191  None  Turbo-fan
# 4     191  None  Turbo-fan
# ..    ...   ...        ...
# 90    140  None  Turbo-fan
# 91    140  None  Turbo-fan
# 92    140  None  Turbo-fan
# 93    140  None  Turbo-fan
# 94    140  None  Turbo-fan
#
# [95 rows x 9 columns]

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE year == 2012", con)
sql_result
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 0   N20904  2012.0  Fixed wing multi engine       BOEING      787-8        2
# 1   N26906  2012.0  Fixed wing multi engine       BOEING      787-8        2
# 2   N27901  2012.0  Fixed wing multi engine       BOEING      787-8        2
# 3   N28457  2012.0  Fixed wing multi engine       BOEING  737-924ER        2
# 4   N34455  2012.0  Fixed wing multi engine       BOEING  737-924ER        2
# ..     ...     ...                      ...          ...        ...      ...
# 90  N8601C  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 91  N8602F  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 92  N8603F  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 93  N8604K  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 94  N8605E  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
#
#     seats speed     engine
# 0     260  None  Turbo-fan
# 1     260  None  Turbo-fan
# 2     260  None  Turbo-fan
# 3     191  None  Turbo-fan
# 4     191  None  Turbo-fan
# ..    ...   ...        ...
# 90    140  None  Turbo-fan
# 91    140  None  Turbo-fan
# 92    140  None  Turbo-fan
# 93    140  None  Turbo-fan
# 94    140  None  Turbo-fan
#
# [95 rows x 9 columns]

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE year != 2012", con)
sql_result
# Out:
#      tailnum    year                     type                   manufacturer  \
# 0     N10156  2004.0  Fixed wing multi engine                        EMBRAER
# 1     N102UW  1998.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 2     N103US  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 3     N104UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 4     N10575  2002.0  Fixed wing multi engine                        EMBRAER
# ...      ...     ...                      ...                            ...
# 3152  N997AT  2002.0  Fixed wing multi engine                         BOEING
# 3153  N997DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 3154  N998AT  2002.0  Fixed wing multi engine                         BOEING
# 3155  N998DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 3156  N999DN  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
#
#           model  engines  seats  speed     engine
# 0     EMB-145XR        2     55    NaN  Turbo-fan
# 1      A320-214        2    182    NaN  Turbo-fan
# 2      A320-214        2    182    NaN  Turbo-fan
# 3      A320-214        2    182    NaN  Turbo-fan
# 4     EMB-145LR        2     55    NaN  Turbo-fan
# ...         ...      ...    ...    ...        ...
# 3152    717-200        2    100    NaN  Turbo-fan
# 3153      MD-88        2    142    NaN  Turbo-fan
# 3154    717-200        2    100    NaN  Turbo-fan
# 3155      MD-88        2    142    NaN  Turbo-jet
# 3156      MD-88        2    142    NaN  Turbo-jet
#
# [3157 rows x 9 columns]

# %%
# nie równa się
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE year <> 2012", con)
sql_result
# Out:
#      tailnum    year                     type                   manufacturer  \
# 0     N10156  2004.0  Fixed wing multi engine                        EMBRAER
# 1     N102UW  1998.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 2     N103US  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 3     N104UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 4     N10575  2002.0  Fixed wing multi engine                        EMBRAER
# ...      ...     ...                      ...                            ...
# 3152  N997AT  2002.0  Fixed wing multi engine                         BOEING
# 3153  N997DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 3154  N998AT  2002.0  Fixed wing multi engine                         BOEING
# 3155  N998DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 3156  N999DN  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
#
#           model  engines  seats  speed     engine
# 0     EMB-145XR        2     55    NaN  Turbo-fan
# 1      A320-214        2    182    NaN  Turbo-fan
# 2      A320-214        2    182    NaN  Turbo-fan
# 3      A320-214        2    182    NaN  Turbo-fan
# 4     EMB-145LR        2     55    NaN  Turbo-fan
# ...         ...      ...    ...    ...        ...
# 3152    717-200        2    100    NaN  Turbo-fan
# 3153      MD-88        2    142    NaN  Turbo-fan
# 3154    717-200        2    100    NaN  Turbo-fan
# 3155      MD-88        2    142    NaN  Turbo-jet
# 3156      MD-88        2    142    NaN  Turbo-jet
#
# [3157 rows x 9 columns]

# %% [markdown]
# ## Składanie warunków

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE year >= 2010 AND year <= 2011", con)
sql_result
# Out:
#     tailnum    year                     type manufacturer     model  engines  \
# 0    N127UW  2010.0  Fixed wing multi engine       AIRBUS  A320-214        2
# 1    N128UW  2010.0  Fixed wing multi engine       AIRBUS  A320-214        2
# 2    N205FR  2010.0  Fixed wing multi engine       AIRBUS  A320-214        2
# 3    N206FR  2010.0  Fixed wing multi engine       AIRBUS  A320-214        2
# 4    N207FR  2010.0  Fixed wing multi engine       AIRBUS  A320-214        2
# ..      ...     ...                      ...          ...       ...      ...
# 109  N965WN  2011.0  Fixed wing multi engine       BOEING   737-7H4        2
# 110  N966WN  2011.0  Fixed wing multi engine       BOEING   737-7H4        2
# 111  N967WN  2011.0  Fixed wing multi engine       BOEING   737-7H4        2
# 112  N968WN  2011.0  Fixed wing multi engine       BOEING   737-7H4        2
# 113  N969WN  2011.0  Fixed wing multi engine       BOEING   737-7H4        2
#
#      seats speed     engine
# 0      182  None  Turbo-fan
# 1      182  None  Turbo-fan
# 2      182  None  Turbo-fan
# 3      182  None  Turbo-fan
# 4      182  None  Turbo-fan
# ..     ...   ...        ...
# 109    140  None  Turbo-fan
# 110    140  None  Turbo-fan
# 111    140  None  Turbo-fan
# 112    140  None  Turbo-fan
# 113    140  None  Turbo-fan
#
# [114 rows x 9 columns]

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE year BETWEEN 2010 AND 2011", con)
sql_result
# Out:
#     tailnum    year                     type manufacturer     model  engines  \
# 0    N127UW  2010.0  Fixed wing multi engine       AIRBUS  A320-214        2
# 1    N128UW  2010.0  Fixed wing multi engine       AIRBUS  A320-214        2
# 2    N205FR  2010.0  Fixed wing multi engine       AIRBUS  A320-214        2
# 3    N206FR  2010.0  Fixed wing multi engine       AIRBUS  A320-214        2
# 4    N207FR  2010.0  Fixed wing multi engine       AIRBUS  A320-214        2
# ..      ...     ...                      ...          ...       ...      ...
# 109  N965WN  2011.0  Fixed wing multi engine       BOEING   737-7H4        2
# 110  N966WN  2011.0  Fixed wing multi engine       BOEING   737-7H4        2
# 111  N967WN  2011.0  Fixed wing multi engine       BOEING   737-7H4        2
# 112  N968WN  2011.0  Fixed wing multi engine       BOEING   737-7H4        2
# 113  N969WN  2011.0  Fixed wing multi engine       BOEING   737-7H4        2
#
#      seats speed     engine
# 0      182  None  Turbo-fan
# 1      182  None  Turbo-fan
# 2      182  None  Turbo-fan
# 3      182  None  Turbo-fan
# 4      182  None  Turbo-fan
# ..     ...   ...        ...
# 109    140  None  Turbo-fan
# 110    140  None  Turbo-fan
# 111    140  None  Turbo-fan
# 112    140  None  Turbo-fan
# 113    140  None  Turbo-fan
#
# [114 rows x 9 columns]

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE year <= 1990 OR year >= 2000", con)
sql_result
# Out:
#      tailnum    year                     type manufacturer      model  \
# 0     N10156  2004.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 1     N10575  2002.0  Fixed wing multi engine      EMBRAER  EMB-145LR
# 2     N11106  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 3     N11107  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# 4     N11109  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR
# ...      ...     ...                      ...          ...        ...
# 2360  N994AT  2002.0  Fixed wing multi engine       BOEING    717-200
# 2361  N995AT  2002.0  Fixed wing multi engine       BOEING    717-200
# 2362  N996AT  2002.0  Fixed wing multi engine       BOEING    717-200
# 2363  N997AT  2002.0  Fixed wing multi engine       BOEING    717-200
# 2364  N998AT  2002.0  Fixed wing multi engine       BOEING    717-200
#
#       engines  seats  speed     engine
# 0           2     55    NaN  Turbo-fan
# 1           2     55    NaN  Turbo-fan
# 2           2     55    NaN  Turbo-fan
# 3           2     55    NaN  Turbo-fan
# 4           2     55    NaN  Turbo-fan
# ...       ...    ...    ...        ...
# 2360        2    100    NaN  Turbo-fan
# 2361        2    100    NaN  Turbo-fan
# 2362        2    100    NaN  Turbo-fan
# 2363        2    100    NaN  Turbo-fan
# 2364        2    100    NaN  Turbo-fan
#
# [2365 rows x 9 columns]

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE NOT year != 2012", con)
sql_result
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 0   N20904  2012.0  Fixed wing multi engine       BOEING      787-8        2
# 1   N26906  2012.0  Fixed wing multi engine       BOEING      787-8        2
# 2   N27901  2012.0  Fixed wing multi engine       BOEING      787-8        2
# 3   N28457  2012.0  Fixed wing multi engine       BOEING  737-924ER        2
# 4   N34455  2012.0  Fixed wing multi engine       BOEING  737-924ER        2
# ..     ...     ...                      ...          ...        ...      ...
# 90  N8601C  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 91  N8602F  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 92  N8603F  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 93  N8604K  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
# 94  N8605E  2012.0  Fixed wing multi engine       BOEING    737-8H4        2
#
#     seats speed     engine
# 0     260  None  Turbo-fan
# 1     260  None  Turbo-fan
# 2     260  None  Turbo-fan
# 3     191  None  Turbo-fan
# 4     191  None  Turbo-fan
# ..    ...   ...        ...
# 90    140  None  Turbo-fan
# 91    140  None  Turbo-fan
# 92    140  None  Turbo-fan
# 93    140  None  Turbo-fan
# 94    140  None  Turbo-fan
#
# [95 rows x 9 columns]

# %% [markdown]
# ## NULL

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE speed IS NOT NULL", con)
sql_result
# Out:
#    tailnum    year                      type       manufacturer        model  \
# 0   N201AA  1959.0  Fixed wing single engine             CESSNA          150
# 1   N202AA  1980.0   Fixed wing multi engine             CESSNA         421C
# 2   N350AA  1980.0   Fixed wing multi engine              PIPER    PA-31-350
# 3   N364AA  1973.0   Fixed wing multi engine             CESSNA         310Q
# 4   N378AA  1963.0  Fixed wing single engine             CESSNA         172E
# 5   N381AA  1956.0   Fixed wing multi engine            DOUGLAS       DC-7BF
# 6   N425AA  1968.0  Fixed wing single engine              PIPER    PA-28-180
# 7   N508AA  1975.0                Rotorcraft               BELL         206B
# 8   N519MQ  1983.0  Fixed wing single engine             CESSNA        A185F
# 9   N525AA  1980.0   Fixed wing multi engine              PIPER    PA-31-350
# 10  N545AA  1976.0  Fixed wing single engine              PIPER   PA-32R-300
# 11  N567AA  1959.0  Fixed wing single engine        DEHAVILLAND  OTTER DHC-3
# 12  N600TR  1979.0   Fixed wing multi engine  MCDONNELL DOUGLAS      DC-9-51
# 13  N615AA  1967.0   Fixed wing multi engine              BEECH       65-A90
# 14  N621AA  1975.0  Fixed wing single engine             CESSNA         172M
# 15  N675MC  1975.0   Fixed wing multi engine  MCDONNELL DOUGLAS      DC-9-51
# 16  N737MQ  1977.0  Fixed wing single engine             CESSNA         172N
# 17  N762NC  1976.0   Fixed wing multi engine  MCDONNELL DOUGLAS      DC-9-51
# 18  N767NC  1977.0   Fixed wing multi engine  MCDONNELL DOUGLAS      DC-9-51
# 19  N774NC  1978.0   Fixed wing multi engine  MCDONNELL DOUGLAS      DC-9-51
# 20  N777NC  1979.0   Fixed wing multi engine  MCDONNELL DOUGLAS      DC-9-51
# 21  N779NC  1979.0   Fixed wing multi engine  MCDONNELL DOUGLAS      DC-9-51
# 22  N782NC  1980.0   Fixed wing multi engine  MCDONNELL DOUGLAS      DC-9-51
#
#     engines  seats  speed         engine
# 0         1      2   90.0  Reciprocating
# 1         2      8   90.0  Reciprocating
# 2         2      8  162.0  Reciprocating
# 3         2      6  167.0  Reciprocating
# 4         1      4  105.0  Reciprocating
# 5         4    102  232.0  Reciprocating
# 6         1      4  107.0  Reciprocating
# 7         1      5  112.0    Turbo-shaft
# 8         1      6  127.0  Reciprocating
# 9         2      8  162.0  Reciprocating
# 10        1      7  126.0  Reciprocating
# 11        1     16   95.0  Reciprocating
# 12        2    139  432.0      Turbo-jet
# 13        2      9  202.0     Turbo-prop
# 14        1      4  108.0        4 Cycle
# 15        2    139  432.0      Turbo-jet
# 16        1      4  105.0  Reciprocating
# 17        2    139  432.0      Turbo-jet
# 18        2    139  432.0      Turbo-jet
# 19        2    139  432.0      Turbo-jet
# 20        2    139  432.0      Turbo-jet
# 21        2    139  432.0      Turbo-jet
# 22        2    139  432.0      Turbo-jet

# %%
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE speed IS NULL", con)
sql_result
# Out:
#      tailnum    year                     type                   manufacturer  \
# 0     N10156  2004.0  Fixed wing multi engine                        EMBRAER
# 1     N102UW  1998.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 2     N103US  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 3     N104UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 4     N10575  2002.0  Fixed wing multi engine                        EMBRAER
# ...      ...     ...                      ...                            ...
# 3294  N997AT  2002.0  Fixed wing multi engine                         BOEING
# 3295  N997DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 3296  N998AT  2002.0  Fixed wing multi engine                         BOEING
# 3297  N998DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 3298  N999DN  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
#
#           model  engines  seats speed     engine
# 0     EMB-145XR        2     55  None  Turbo-fan
# 1      A320-214        2    182  None  Turbo-fan
# 2      A320-214        2    182  None  Turbo-fan
# 3      A320-214        2    182  None  Turbo-fan
# 4     EMB-145LR        2     55  None  Turbo-fan
# ...         ...      ...    ...   ...        ...
# 3294    717-200        2    100  None  Turbo-fan
# 3295      MD-88        2    142  None  Turbo-fan
# 3296    717-200        2    100  None  Turbo-fan
# 3297      MD-88        2    142  None  Turbo-jet
# 3298      MD-88        2    142  None  Turbo-jet
#
# [3299 rows x 9 columns]

# %% [markdown]
# ## IN

# %%
sql_result = pd.read_sql_query("""
SELECT * FROM planes
WHERE manufacturer IN ('EMBRAER', 'AIRBUS INDUSTRIE')""", con)
sql_result
# Out:
#     tailnum    year                     type      manufacturer  \
# 0    N10156  2004.0  Fixed wing multi engine           EMBRAER
# 1    N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE
# 2    N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE
# 3    N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE
# 4    N10575  2002.0  Fixed wing multi engine           EMBRAER
# ..      ...     ...                      ...               ...
# 694  N959UW  2008.0  Fixed wing multi engine           EMBRAER
# 695  N961UW  2008.0  Fixed wing multi engine           EMBRAER
# 696  N963UW  2008.0  Fixed wing multi engine           EMBRAER
# 697  N965UW  2008.0  Fixed wing multi engine           EMBRAER
# 698  N967UW  2008.0  Fixed wing multi engine           EMBRAER
#
#                model  engines  seats speed     engine
# 0          EMB-145XR        2     55  None  Turbo-fan
# 1           A320-214        2    182  None  Turbo-fan
# 2           A320-214        2    182  None  Turbo-fan
# 3           A320-214        2    182  None  Turbo-fan
# 4          EMB-145LR        2     55  None  Turbo-fan
# ..               ...      ...    ...   ...        ...
# 694  ERJ 190-100 IGW        2     20  None  Turbo-fan
# 695  ERJ 190-100 IGW        2     20  None  Turbo-fan
# 696  ERJ 190-100 IGW        2     20  None  Turbo-fan
# 697  ERJ 190-100 IGW        2     20  None  Turbo-fan
# 698  ERJ 190-100 IGW        2     20  None  Turbo-fan
#
# [699 rows x 9 columns]

# %% [markdown]
# # DISTINCT

# %%
# unikatowe wartości w kolumnie year
sql_result = pd.read_sql_query("SELECT DISTINCT year FROM \
                               planes", con)
sql_result
# Out:
#       year
# 0   2004.0
# 1   1998.0
# 2   1999.0
# 3   2002.0
# 4   2003.0
# 5   2005.0
# 6   2006.0
# 7   2000.0
# 8   2001.0
# 9   1994.0
# 10  1995.0
# 11  1996.0
# 12  1987.0
# 13  2009.0
# 14  2010.0
# 15  1991.0
# 16  1997.0
# 17     NaN
# 18  1965.0
# 19  2007.0
# 20  1990.0
# 21  2013.0
# 22  2008.0
# 23  1992.0
# 24  1993.0
# 25  1959.0
# 26  1980.0
# 27  2011.0
# 28  2012.0
# 29  1988.0
# 30  1985.0
# 31  1986.0
# 32  1989.0
# 33  1973.0
# 34  1978.0
# 35  1963.0
# 36  1956.0
# 37  1972.0
# 38  1968.0
# 39  1975.0
# 40  1979.0
# 41  1983.0
# 42  1976.0
# 43  1984.0
# 44  1967.0
# 45  1977.0
# 46  1974.0

# %%
# unikatowe pary w kolumnach type, manufacturer 
sql_result = pd.read_sql_query("SELECT DISTINCT type, manufacturer FROM \
                               planes", con)
sql_result
# Out:
#                         type                   manufacturer
# 0    Fixed wing multi engine                        EMBRAER
# 1    Fixed wing multi engine               AIRBUS INDUSTRIE
# 2    Fixed wing multi engine                         BOEING
# 3    Fixed wing multi engine                         AIRBUS
# 4    Fixed wing multi engine                 BOMBARDIER INC
# 5   Fixed wing single engine                         CESSNA
# 6    Fixed wing multi engine                         CESSNA
# 7   Fixed wing single engine                    JOHN G HESS
# 8    Fixed wing multi engine           GULFSTREAM AEROSPACE
# 9                 Rotorcraft                       SIKORSKY
# 10   Fixed wing multi engine                          PIPER
# 11                Rotorcraft                     AGUSTA SPA
# 12  Fixed wing single engine                          PIPER
# 13  Fixed wing single engine                    PAIR MIKE E
# 14   Fixed wing multi engine                        DOUGLAS
# 15   Fixed wing multi engine                          BEECH
# 16                Rotorcraft                           BELL
# 17  Fixed wing single engine             AVIAT AIRCRAFT INC
# 18  Fixed wing single engine                   STEWART MACO
# 19   Fixed wing multi engine                    LEARJET INC
# 20   Fixed wing multi engine              MCDONNELL DOUGLAS
# 21  Fixed wing single engine             CIRRUS DESIGN CORP
# 22  Fixed wing single engine             HURLEY JAMES LARRY
# 23  Fixed wing single engine                   KILDALL GARY
# 24  Fixed wing single engine                LAMBERT RICHARD
# 25  Fixed wing single engine                  BARKER JACK L
# 26  Fixed wing single engine          AMERICAN AIRCRAFT INC
# 27                Rotorcraft         ROBINSON HELICOPTER CO
# 28  Fixed wing single engine                 FRIEDEMANN JON
# 29  Fixed wing single engine                LEBLANC GLENN T
# 30  Fixed wing single engine                     MARZ BARRY
# 31  Fixed wing single engine                    DEHAVILLAND
# 32   Fixed wing multi engine                       CANADAIR
# 33   Fixed wing multi engine                   CANADAIR LTD
# 34   Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 35   Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 36   Fixed wing multi engine         AVIONS MARCEL DASSAULT

# %% [markdown]
# # LIKE

# %% [markdown]
# Służy do dopasowywania się do napisów w warunkach logicznych.

# %% [markdown]
# `%` to dowolny, być może pusty, ciąg znaków

# %%
sql_result = pd.read_sql_query("SELECT DISTINCT type FROM planes", con)
sql_result
# Out:
#                        type
# 0   Fixed wing multi engine
# 1  Fixed wing single engine
# 2                Rotorcraft

# %%
sql_result = pd.read_sql_query("SELECT DISTINCT type FROM planes WHERE type LIKE 'engine'", con)
sql_result
# Out:
# Empty DataFrame
# Columns: [type]
# Index: []

# %%
sql_result = pd.read_sql_query("SELECT DISTINCT type FROM planes WHERE type LIKE 'Fixed wing multi engine'", con)
sql_result
# Out:
#                       type
# 0  Fixed wing multi engine

# %%
sql_result = pd.read_sql_query("SELECT DISTINCT type FROM planes WHERE type LIKE '%engine'", con)
sql_result
# Out:
#                        type
# 0   Fixed wing multi engine
# 1  Fixed wing single engine

# %%
sql_result = pd.read_sql_query("SELECT DISTINCT type FROM planes WHERE type LIKE '%wing'", con)
sql_result
# Out:
# Empty DataFrame
# Columns: [type]
# Index: []

# %%
sql_result = pd.read_sql_query("SELECT DISTINCT type FROM planes WHERE type LIKE '%wing%'", con)
sql_result
# Out:
#                        type
# 0   Fixed wing multi engine
# 1  Fixed wing single engine

# %%
sql_result = pd.read_sql_query("SELECT DISTINCT type FROM planes WHERE type LIKE '%engine%'", con)
sql_result
# Out:
#                        type
# 0   Fixed wing multi engine
# 1  Fixed wing single engine

# %% [markdown]
# `_` - pojedynczy znak

# %%
sql_result = pd.read_sql_query("SELECT DISTINCT type FROM planes WHERE type LIKE '%_ngin_'", con)
sql_result
# Out:
#                        type
# 0   Fixed wing multi engine
# 1  Fixed wing single engine

# %%
# wybieram z dokładnie 6 znakami
sql_result = pd.read_sql_query("SELECT * FROM planes WHERE manufacturer LIKE '______'", con)
sql_result
# Out:
#      tailnum    year                     type manufacturer    model  engines  \
# 0     N11206  2000.0  Fixed wing multi engine       BOEING  737-824        2
# 1     N1200K  1998.0  Fixed wing multi engine       BOEING  767-332        2
# 2     N1201P  1998.0  Fixed wing multi engine       BOEING  767-332        2
# 3     N12109  1994.0  Fixed wing multi engine       BOEING  757-224        2
# 4     N12114  1995.0  Fixed wing multi engine       BOEING  757-224        2
# ...      ...     ...                      ...          ...      ...      ...
# 1970  N994AT  2002.0  Fixed wing multi engine       BOEING  717-200        2
# 1971  N995AT  2002.0  Fixed wing multi engine       BOEING  717-200        2
# 1972  N996AT  2002.0  Fixed wing multi engine       BOEING  717-200        2
# 1973  N997AT  2002.0  Fixed wing multi engine       BOEING  717-200        2
# 1974  N998AT  2002.0  Fixed wing multi engine       BOEING  717-200        2
#
#       seats  speed     engine
# 0       149    NaN  Turbo-fan
# 1       330    NaN  Turbo-fan
# 2       330    NaN  Turbo-fan
# 3       178    NaN  Turbo-jet
# 4       178    NaN  Turbo-jet
# ...     ...    ...        ...
# 1970    100    NaN  Turbo-fan
# 1971    100    NaN  Turbo-fan
# 1972    100    NaN  Turbo-fan
# 1973    100    NaN  Turbo-fan
# 1974    100    NaN  Turbo-fan
#
# [1975 rows x 9 columns]

# %% [markdown]
# # Sortowanie

# %%
# domyślnie sortuje rosnąco (ascending)
sql_result = pd.read_sql_query("""
SELECT * FROM planes ORDER BY year
""", con)
sql_result
# Out:
#      tailnum    year                     type      manufacturer      model  \
# 0     N14558     NaN  Fixed wing multi engine           EMBRAER  EMB-145LR
# 1     N15555     NaN  Fixed wing multi engine           EMBRAER  EMB-145LR
# 2     N15574     NaN  Fixed wing multi engine           EMBRAER  EMB-145LR
# 3     N174US     NaN  Fixed wing multi engine  AIRBUS INDUSTRIE   A321-211
# 4     N177US     NaN  Fixed wing multi engine  AIRBUS INDUSTRIE   A321-211
# ...      ...     ...                      ...               ...        ...
# 3317  N8620H  2013.0  Fixed wing multi engine            BOEING    737-8H4
# 3318  N8621A  2013.0  Fixed wing multi engine            BOEING    737-8H4
# 3319  N903JB  2013.0  Fixed wing multi engine            AIRBUS   A321-231
# 3320  N907JB  2013.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A321-231
# 3321  N913JB  2013.0  Fixed wing multi engine            AIRBUS   A321-231
#
#       engines  seats  speed     engine
# 0           2     55    NaN  Turbo-fan
# 1           2     55    NaN  Turbo-fan
# 2           2     55    NaN  Turbo-fan
# 3           2    199    NaN  Turbo-jet
# 4           2    199    NaN  Turbo-jet
# ...       ...    ...    ...        ...
# 3317        2    140    NaN  Turbo-fan
# 3318        2    140    NaN  Turbo-fan
# 3319        2    379    NaN  Turbo-fan
# 3320        2    379    NaN  Turbo-fan
# 3321        2    379    NaN  Turbo-fan
#
# [3322 rows x 9 columns]

# %%
# order by występuje na końcu zapytania
sql_result = pd.read_sql_query("""
SELECT DISTINCT year
FROM planes 
WHERE manufacturer = 'BOEING' 
ORDER BY year""", con)
sql_result
# Out:
#       year
# 0      NaN
# 1   1965.0
# 2   1984.0
# 3   1985.0
# 4   1986.0
# 5   1987.0
# 6   1988.0
# 7   1989.0
# 8   1990.0
# 9   1991.0
# 10  1992.0
# 11  1993.0
# 12  1994.0
# 13  1995.0
# 14  1996.0
# 15  1997.0
# 16  1998.0
# 17  1999.0
# 18  2000.0
# 19  2001.0
# 20  2002.0
# 21  2003.0
# 22  2004.0
# 23  2005.0
# 24  2006.0
# 25  2007.0
# 26  2008.0
# 27  2009.0
# 28  2010.0
# 29  2011.0
# 30  2012.0
# 31  2013.0

# %%
# domyślnie sortuje rosnąco (ascending, ASC)
# teoretycznie możemy pisać ASC w zapytaniu, ale nie ma potrzeby
# jeśli chcemy zmienić kierunek sortowania na malejący, to dopisujemy DESC jak descending
sql_result = pd.read_sql_query("""
SELECT DISTINCT year
FROM planes 
WHERE manufacturer = 'BOEING' 
ORDER BY year DESC""", con)
sql_result
# Out:
#       year
# 0   2013.0
# 1   2012.0
# 2   2011.0
# 3   2010.0
# 4   2009.0
# 5   2008.0
# 6   2007.0
# 7   2006.0
# 8   2005.0
# 9   2004.0
# 10  2003.0
# 11  2002.0
# 12  2001.0
# 13  2000.0
# 14  1999.0
# 15  1998.0
# 16  1997.0
# 17  1996.0
# 18  1995.0
# 19  1994.0
# 20  1993.0
# 21  1992.0
# 22  1991.0
# 23  1990.0
# 24  1989.0
# 25  1988.0
# 26  1987.0
# 27  1986.0
# 28  1985.0
# 29  1984.0
# 30  1965.0
# 31     NaN

# %%
# sortujemy po pierwszej kolumnie globalnie, jak jest na niej remis, to sortujemy
# po kolejnej kolumnie
sql_result = pd.read_sql_query("""
SELECT DISTINCT year, manufacturer
FROM planes
ORDER BY year DESC, manufacturer""", con)
sql_result.head(10)
# Out:
#      year            manufacturer
# 0  2013.0                  AIRBUS
# 1  2013.0        AIRBUS INDUSTRIE
# 2  2013.0                  BOEING
# 3  2013.0          BOMBARDIER INC
# 4  2013.0                 EMBRAER
# 5  2012.0                  AIRBUS
# 6  2012.0                  BOEING
# 7  2012.0                 EMBRAER
# 8  2012.0  ROBINSON HELICOPTER CO
# 9  2011.0                  AIRBUS

# %% [markdown]
# # Grupowanie

# %%
sql_result = pd.read_sql_query("""
SELECT manufacturer, COUNT(*)
FROM planes
GROUP BY manufacturer
""", con)
sql_result
# Out:
#                      manufacturer  COUNT(*)
# 0                      AGUSTA SPA         1
# 1                          AIRBUS       336
# 2                AIRBUS INDUSTRIE       400
# 3           AMERICAN AIRCRAFT INC         2
# 4              AVIAT AIRCRAFT INC         1
# 5          AVIONS MARCEL DASSAULT         1
# 6                   BARKER JACK L         1
# 7                           BEECH         2
# 8                            BELL         2
# 9                          BOEING      1630
# 10                 BOMBARDIER INC       368
# 11                       CANADAIR         9
# 12                   CANADAIR LTD         1
# 13                         CESSNA         9
# 14             CIRRUS DESIGN CORP         1
# 15                    DEHAVILLAND         1
# 16                        DOUGLAS         1
# 17                        EMBRAER       299
# 18                 FRIEDEMANN JON         1
# 19           GULFSTREAM AEROSPACE         2
# 20             HURLEY JAMES LARRY         1
# 21                    JOHN G HESS         1
# 22                   KILDALL GARY         1
# 23                LAMBERT RICHARD         1
# 24                    LEARJET INC         1
# 25                LEBLANC GLENN T         1
# 26                     MARZ BARRY         1
# 27              MCDONNELL DOUGLAS       120
# 28  MCDONNELL DOUGLAS AIRCRAFT CO       103
# 29  MCDONNELL DOUGLAS CORPORATION        14
# 30                    PAIR MIKE E         1
# 31                          PIPER         5
# 32         ROBINSON HELICOPTER CO         1
# 33                       SIKORSKY         1
# 34                   STEWART MACO         2

# %%
# count(*) - ile wierszy jest w grupie
# count(kolumna) - ile wierszy w grupie ma niebrakującą wartość w kolumnie "kolumna"
sql_result = pd.read_sql_query("""
SELECT manufacturer, COUNT(speed)
FROM planes
GROUP BY manufacturer
""", con)
sql_result
# Out:
#                      manufacturer  COUNT(speed)
# 0                      AGUSTA SPA             0
# 1                          AIRBUS             0
# 2                AIRBUS INDUSTRIE             0
# 3           AMERICAN AIRCRAFT INC             0
# 4              AVIAT AIRCRAFT INC             0
# 5          AVIONS MARCEL DASSAULT             0
# 6                   BARKER JACK L             0
# 7                           BEECH             1
# 8                            BELL             1
# 9                          BOEING             0
# 10                 BOMBARDIER INC             0
# 11                       CANADAIR             0
# 12                   CANADAIR LTD             0
# 13                         CESSNA             7
# 14             CIRRUS DESIGN CORP             0
# 15                    DEHAVILLAND             1
# 16                        DOUGLAS             1
# 17                        EMBRAER             0
# 18                 FRIEDEMANN JON             0
# 19           GULFSTREAM AEROSPACE             0
# 20             HURLEY JAMES LARRY             0
# 21                    JOHN G HESS             0
# 22                   KILDALL GARY             0
# 23                LAMBERT RICHARD             0
# 24                    LEARJET INC             0
# 25                LEBLANC GLENN T             0
# 26                     MARZ BARRY             0
# 27              MCDONNELL DOUGLAS             8
# 28  MCDONNELL DOUGLAS AIRCRAFT CO             0
# 29  MCDONNELL DOUGLAS CORPORATION             0
# 30                    PAIR MIKE E             0
# 31                          PIPER             4
# 32         ROBINSON HELICOPTER CO             0
# 33                       SIKORSKY             0
# 34                   STEWART MACO             0

# %%
sql_result = pd.read_sql_query("""
SELECT manufacturer, COUNT(*) AS licznosc
FROM planes
GROUP BY manufacturer
""", con)
sql_result
# Out:
#                      manufacturer  licznosc
# 0                      AGUSTA SPA         1
# 1                          AIRBUS       336
# 2                AIRBUS INDUSTRIE       400
# 3           AMERICAN AIRCRAFT INC         2
# 4              AVIAT AIRCRAFT INC         1
# 5          AVIONS MARCEL DASSAULT         1
# 6                   BARKER JACK L         1
# 7                           BEECH         2
# 8                            BELL         2
# 9                          BOEING      1630
# 10                 BOMBARDIER INC       368
# 11                       CANADAIR         9
# 12                   CANADAIR LTD         1
# 13                         CESSNA         9
# 14             CIRRUS DESIGN CORP         1
# 15                    DEHAVILLAND         1
# 16                        DOUGLAS         1
# 17                        EMBRAER       299
# 18                 FRIEDEMANN JON         1
# 19           GULFSTREAM AEROSPACE         2
# 20             HURLEY JAMES LARRY         1
# 21                    JOHN G HESS         1
# 22                   KILDALL GARY         1
# 23                LAMBERT RICHARD         1
# 24                    LEARJET INC         1
# 25                LEBLANC GLENN T         1
# 26                     MARZ BARRY         1
# 27              MCDONNELL DOUGLAS       120
# 28  MCDONNELL DOUGLAS AIRCRAFT CO       103
# 29  MCDONNELL DOUGLAS CORPORATION        14
# 30                    PAIR MIKE E         1
# 31                          PIPER         5
# 32         ROBINSON HELICOPTER CO         1
# 33                       SIKORSKY         1
# 34                   STEWART MACO         2

# %%
sql_result = pd.read_sql_query("""
SELECT manufacturer, engine, COUNT(*) AS licznosc
FROM planes
GROUP BY manufacturer, engine
""", con)
sql_result
# Out:
#                      manufacturer         engine  licznosc
# 0                      AGUSTA SPA    Turbo-shaft         1
# 1                          AIRBUS      Turbo-fan       331
# 2                          AIRBUS      Turbo-jet         5
# 3                AIRBUS INDUSTRIE      Turbo-fan       270
# 4                AIRBUS INDUSTRIE      Turbo-jet       130
# 5           AMERICAN AIRCRAFT INC  Reciprocating         2
# 6              AVIAT AIRCRAFT INC  Reciprocating         1
# 7          AVIONS MARCEL DASSAULT      Turbo-fan         1
# 8                   BARKER JACK L  Reciprocating         1
# 9                           BEECH     Turbo-prop         2
# 10                           BELL    Turbo-shaft         2
# 11                         BOEING      Turbo-fan      1276
# 12                         BOEING      Turbo-jet       354
# 13                 BOMBARDIER INC      Turbo-fan       368
# 14                       CANADAIR      Turbo-fan         9
# 15                   CANADAIR LTD      Turbo-jet         1
# 16                         CESSNA        4 Cycle         1
# 17                         CESSNA  Reciprocating         7
# 18                         CESSNA      Turbo-fan         1
# 19             CIRRUS DESIGN CORP  Reciprocating         1
# 20                    DEHAVILLAND  Reciprocating         1
# 21                        DOUGLAS  Reciprocating         1
# 22                        EMBRAER      Turbo-fan       298
# 23                        EMBRAER      Turbo-jet         1
# 24                 FRIEDEMANN JON  Reciprocating         1
# 25           GULFSTREAM AEROSPACE      Turbo-fan         1
# 26           GULFSTREAM AEROSPACE      Turbo-jet         1
# 27             HURLEY JAMES LARRY  Reciprocating         1
# 28                    JOHN G HESS        4 Cycle         1
# 29                   KILDALL GARY  Reciprocating         1
# 30                LAMBERT RICHARD  Reciprocating         1
# 31                    LEARJET INC      Turbo-fan         1
# 32                LEBLANC GLENN T  Reciprocating         1
# 33                     MARZ BARRY  Reciprocating         1
# 34              MCDONNELL DOUGLAS      Turbo-fan        91
# 35              MCDONNELL DOUGLAS      Turbo-jet        29
# 36  MCDONNELL DOUGLAS AIRCRAFT CO      Turbo-fan       103
# 37  MCDONNELL DOUGLAS CORPORATION      Turbo-jet        14
# 38                    PAIR MIKE E  Reciprocating         1
# 39                          PIPER  Reciprocating         5
# 40         ROBINSON HELICOPTER CO    Turbo-shaft         1
# 41                       SIKORSKY    Turbo-shaft         1
# 42                   STEWART MACO  Reciprocating         2

# %%
# o ile nie wiemy dokładnie co robimy,
# nie wstawiamy do SELECTa dowolnych kolumn
# Wstawiamy tylko kolumny po których grupujemy
# i funkcje agregujące
# Taka "dowolna" kolumna, jak year w przykładzie, daje nam losową
# wartość z tej kolumny dla jakiegoś wiersza w grupie (ani nie najmniejszą,
# ani największą)
sql_result = pd.read_sql_query("""
SELECT manufacturer, engine, year, COUNT(*) AS licznosc
FROM planes
GROUP BY manufacturer, engine
""", con)
sql_result
# Out:
#                      manufacturer         engine    year  licznosc
# 0                      AGUSTA SPA    Turbo-shaft  2001.0         1
# 1                          AIRBUS      Turbo-fan  2009.0       331
# 2                          AIRBUS      Turbo-jet  2002.0         5
# 3                AIRBUS INDUSTRIE      Turbo-fan  1998.0       270
# 4                AIRBUS INDUSTRIE      Turbo-jet  2001.0       130
# 5           AMERICAN AIRCRAFT INC  Reciprocating     NaN         2
# 6              AVIAT AIRCRAFT INC  Reciprocating  2007.0         1
# 7          AVIONS MARCEL DASSAULT      Turbo-fan  1986.0         1
# 8                   BARKER JACK L  Reciprocating     NaN         1
# 9                           BEECH     Turbo-prop  1972.0         2
# 10                           BELL    Turbo-shaft  1994.0         2
# 11                         BOEING      Turbo-fan  2000.0      1276
# 12                         BOEING      Turbo-jet  1994.0       354
# 13                 BOMBARDIER INC      Turbo-fan  2009.0       368
# 14                       CANADAIR      Turbo-fan  1997.0         9
# 15                   CANADAIR LTD      Turbo-jet  1974.0         1
# 16                         CESSNA        4 Cycle  1975.0         1
# 17                         CESSNA  Reciprocating  1959.0         7
# 18                         CESSNA      Turbo-fan  1979.0         1
# 19             CIRRUS DESIGN CORP  Reciprocating  2007.0         1
# 20                    DEHAVILLAND  Reciprocating  1959.0         1
# 21                        DOUGLAS  Reciprocating  1956.0         1
# 22                        EMBRAER      Turbo-fan  2004.0       298
# 23                        EMBRAER      Turbo-jet  1999.0         1
# 24                 FRIEDEMANN JON  Reciprocating  2007.0         1
# 25           GULFSTREAM AEROSPACE      Turbo-fan  1992.0         1
# 26           GULFSTREAM AEROSPACE      Turbo-jet  1976.0         1
# 27             HURLEY JAMES LARRY  Reciprocating     NaN         1
# 28                    JOHN G HESS        4 Cycle     NaN         1
# 29                   KILDALL GARY  Reciprocating  1985.0         1
# 30                LAMBERT RICHARD  Reciprocating     NaN         1
# 31                    LEARJET INC      Turbo-fan     NaN         1
# 32                LEBLANC GLENN T  Reciprocating  1985.0         1
# 33                     MARZ BARRY  Reciprocating  1993.0         1
# 34              MCDONNELL DOUGLAS      Turbo-fan  1986.0        91
# 35              MCDONNELL DOUGLAS      Turbo-jet  1979.0        29
# 36  MCDONNELL DOUGLAS AIRCRAFT CO      Turbo-fan  1987.0       103
# 37  MCDONNELL DOUGLAS CORPORATION      Turbo-jet  1992.0        14
# 38                    PAIR MIKE E  Reciprocating     NaN         1
# 39                          PIPER  Reciprocating  1980.0         5
# 40         ROBINSON HELICOPTER CO    Turbo-shaft  2012.0         1
# 41                       SIKORSKY    Turbo-shaft  1985.0         1
# 42                   STEWART MACO  Reciprocating  1985.0         2

# %%
sql_result = pd.read_sql_query("""
SELECT manufacturer, engine, MIN(year), AVG(year), MAX(year)
FROM planes
GROUP BY manufacturer, engine
""", con)
sql_result
# Out:
#                      manufacturer         engine  MIN(year)    AVG(year)  \
# 0                      AGUSTA SPA    Turbo-shaft     2001.0  2001.000000
# 1                          AIRBUS      Turbo-fan     2002.0  2007.281734
# 2                          AIRBUS      Turbo-jet     2002.0  2002.000000
# 3                AIRBUS INDUSTRIE      Turbo-fan     1992.0  1998.599251
# 4                AIRBUS INDUSTRIE      Turbo-jet     1989.0  1997.439024
# 5           AMERICAN AIRCRAFT INC  Reciprocating        NaN          NaN
# 6              AVIAT AIRCRAFT INC  Reciprocating     2007.0  2007.000000
# 7          AVIONS MARCEL DASSAULT      Turbo-fan     1986.0  1986.000000
# 8                   BARKER JACK L  Reciprocating        NaN          NaN
# 9                           BEECH     Turbo-prop     1967.0  1969.500000
# 10                           BELL    Turbo-shaft     1975.0  1984.500000
# 11                         BOEING      Turbo-fan     1965.0  2001.210400
# 12                         BOEING      Turbo-jet     1984.0  1996.368272
# 13                 BOMBARDIER INC      Turbo-fan     1998.0  2004.486188
# 14                       CANADAIR      Turbo-fan     1997.0  1997.333333
# 15                   CANADAIR LTD      Turbo-jet     1974.0  1974.000000
# 16                         CESSNA        4 Cycle     1975.0  1975.000000
# 17                         CESSNA  Reciprocating     1959.0  1971.142857
# 18                         CESSNA      Turbo-fan     1979.0  1979.000000
# 19             CIRRUS DESIGN CORP  Reciprocating     2007.0  2007.000000
# 20                    DEHAVILLAND  Reciprocating     1959.0  1959.000000
# 21                        DOUGLAS  Reciprocating     1956.0  1956.000000
# 22                        EMBRAER      Turbo-fan     1998.0  2003.613014
# 23                        EMBRAER      Turbo-jet     1999.0  1999.000000
# 24                 FRIEDEMANN JON  Reciprocating     2007.0  2007.000000
# 25           GULFSTREAM AEROSPACE      Turbo-fan     1992.0  1992.000000
# 26           GULFSTREAM AEROSPACE      Turbo-jet     1976.0  1976.000000
# 27             HURLEY JAMES LARRY  Reciprocating        NaN          NaN
# 28                    JOHN G HESS        4 Cycle        NaN          NaN
# 29                   KILDALL GARY  Reciprocating     1985.0  1985.000000
# 30                LAMBERT RICHARD  Reciprocating        NaN          NaN
# 31                    LEARJET INC      Turbo-fan        NaN          NaN
# 32                LEBLANC GLENN T  Reciprocating     1985.0  1985.000000
# 33                     MARZ BARRY  Reciprocating     1993.0  1993.000000
# 34              MCDONNELL DOUGLAS      Turbo-fan     1986.0  1989.704545
# 35              MCDONNELL DOUGLAS      Turbo-jet     1975.0  1990.714286
# 36  MCDONNELL DOUGLAS AIRCRAFT CO      Turbo-fan     1987.0  1989.737864
# 37  MCDONNELL DOUGLAS CORPORATION      Turbo-jet     1991.0  1991.928571
# 38                    PAIR MIKE E  Reciprocating        NaN          NaN
# 39                          PIPER  Reciprocating     1968.0  1976.400000
# 40         ROBINSON HELICOPTER CO    Turbo-shaft     2012.0  2012.000000
# 41                       SIKORSKY    Turbo-shaft     1985.0  1985.000000
# 42                   STEWART MACO  Reciprocating     1985.0  1985.000000
#
#     MAX(year)
# 0      2001.0
# 1      2013.0
# 2      2002.0
# 3      2013.0
# 4      2004.0
# 5         NaN
# 6      2007.0
# 7      1986.0
# 8         NaN
# 9      1972.0
# 10     1994.0
# 11     2013.0
# 12     2005.0
# 13     2013.0
# 14     1998.0
# 15     1974.0
# 16     1975.0
# 17     1983.0
# 18     1979.0
# 19     2007.0
# 20     1959.0
# 21     1956.0
# 22     2013.0
# 23     1999.0
# 24     2007.0
# 25     1992.0
# 26     1976.0
# 27        NaN
# 28        NaN
# 29     1985.0
# 30        NaN
# 31        NaN
# 32     1985.0
# 33     1993.0
# 34     1997.0
# 35     1998.0
# 36     1993.0
# 37     1992.0
# 38        NaN
# 39     1980.0
# 40     2012.0
# 41     1985.0
# 42     1985.0

# %%
# HAVING to taki trochę WHERE, ale wykonuje się PO pogrupowaniu
# Używamy go żeby filtrować wyniki funkcji agregujących
sql_result = pd.read_sql_query("""
SELECT manufacturer, engine, MIN(year), AVG(year)
FROM planes
GROUP BY manufacturer, engine
HAVING MIN(year) > 2000 AND AVG(year) > 2002
""", con)
sql_result
# Out:
#              manufacturer         engine  MIN(year)    AVG(year)
# 0                  AIRBUS      Turbo-fan     2002.0  2007.281734
# 1      AVIAT AIRCRAFT INC  Reciprocating     2007.0  2007.000000
# 2      CIRRUS DESIGN CORP  Reciprocating     2007.0  2007.000000
# 3          FRIEDEMANN JON  Reciprocating     2007.0  2007.000000
# 4  ROBINSON HELICOPTER CO    Turbo-shaft     2012.0  2012.000000

# %%
sql_result = pd.read_sql_query("""
SELECT manufacturer, engine, MIN(year) as minimum, AVG(year) as srednia
FROM planes
GROUP BY manufacturer, engine
HAVING minimum > 2000 AND srednia > 2002
""", con)
sql_result
# Out:
#              manufacturer         engine  minimum      srednia
# 0                  AIRBUS      Turbo-fan   2002.0  2007.281734
# 1      AVIAT AIRCRAFT INC  Reciprocating   2007.0  2007.000000
# 2      CIRRUS DESIGN CORP  Reciprocating   2007.0  2007.000000
# 3          FRIEDEMANN JON  Reciprocating   2007.0  2007.000000
# 4  ROBINSON HELICOPTER CO    Turbo-shaft   2012.0  2012.000000

# %%
# można używać numerów zamiast nazw kolumn
# zadziała też przy ORDER BY
sql_result = pd.read_sql_query("""
SELECT manufacturer, engine, MIN(year) as minimum, AVG(year) as srednia
FROM planes
GROUP BY 1, 2
HAVING minimum > 2000 AND srednia > 2002
""", con)
sql_result
# Out:
#              manufacturer         engine  minimum      srednia
# 0                  AIRBUS      Turbo-fan   2002.0  2007.281734
# 1      AVIAT AIRCRAFT INC  Reciprocating   2007.0  2007.000000
# 2      CIRRUS DESIGN CORP  Reciprocating   2007.0  2007.000000
# 3          FRIEDEMANN JON  Reciprocating   2007.0  2007.000000
# 4  ROBINSON HELICOPTER CO    Turbo-shaft   2012.0  2012.000000

# %%
# można używać numerów zamiast nazw kolumn
# zadziała też przy ORDER BY
sql_result = pd.read_sql_query("""
SELECT manufacturer, engine, MIN(year) as minimum, AVG(year) as srednia
FROM planes
GROUP BY 1, 2
HAVING minimum > 2000 AND srednia > 2002
ORDER BY 2 DESC, 1
""", con)
sql_result
# Out:
#              manufacturer         engine  minimum      srednia
# 0  ROBINSON HELICOPTER CO    Turbo-shaft   2012.0  2012.000000
# 1                  AIRBUS      Turbo-fan   2002.0  2007.281734
# 2      AVIAT AIRCRAFT INC  Reciprocating   2007.0  2007.000000
# 3      CIRRUS DESIGN CORP  Reciprocating   2007.0  2007.000000
# 4          FRIEDEMANN JON  Reciprocating   2007.0  2007.000000

# %%
# where przed pogrupowaniem (na kolumnach)
# having po pogrupowaniu (na funkcjach agregujących)
sql_result = pd.read_sql_query("""
SELECT manufacturer, engine, MIN(year) as minimum, AVG(year) as srednia
FROM planes
WHERE seats > 200
GROUP BY 1, 2
HAVING minimum > 2000 AND srednia > 2002
""", con)
sql_result
# Out:
#        manufacturer     engine  minimum      srednia
# 0            AIRBUS  Turbo-fan   2004.0  2010.661538
# 1  AIRBUS INDUSTRIE  Turbo-fan   2013.0  2013.000000
# 2  AIRBUS INDUSTRIE  Turbo-jet   2004.0  2004.000000

# %% [markdown]
# # Join

# %%
sql_result = pd.read_sql_query("""
SELECT *
FROM flights
LIMIT 3
""", con)
sql_result
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
#
#    distance  hour  minute            time_hour
# 0      1400     5      15  2013-01-01 05:00:00
# 1      1416     5      29  2013-01-01 05:00:00
# 2      1089     5      40  2013-01-01 05:00:00

# %%
sql_result = pd.read_sql_query("""
SELECT *
FROM airlines
LIMIT 10
""", con)
sql_result
# Out:
#   carrier                         name
# 0      9E            Endeavor Air Inc.
# 1      AA       American Airlines Inc.
# 2      AS         Alaska Airlines Inc.
# 3      B6              JetBlue Airways
# 4      DL         Delta Air Lines Inc.
# 5      EV     ExpressJet Airlines Inc.
# 6      F9       Frontier Airlines Inc.
# 7      FL  AirTran Airways Corporation
# 8      HA       Hawaiian Airlines Inc.
# 9      MQ                    Envoy Air

# %%
# domyślnie jest inner join
# ale możemy zamiast JOIN napisać np. LEFT JOIN
sql_result = pd.read_sql_query("""
SELECT flights.carrier, flights.tailnum, airlines.name
FROM flights
JOIN airlines
ON flights.carrier = airlines.carrier
""", con)
sql_result
# Out:
#        carrier tailnum                    name
# 0           UA  N14228   United Air Lines Inc.
# 1           UA  N24211   United Air Lines Inc.
# 2           AA  N619AA  American Airlines Inc.
# 3           B6  N804JB         JetBlue Airways
# 4           DL  N668DN    Delta Air Lines Inc.
# ...        ...     ...                     ...
# 336771      9E    None       Endeavor Air Inc.
# 336772      9E    None       Endeavor Air Inc.
# 336773      MQ  N535MQ               Envoy Air
# 336774      MQ  N511MQ               Envoy Air
# 336775      MQ  N839MQ               Envoy Air
#
# [336776 rows x 3 columns]

# %%
sql_result = pd.read_sql_query("""
SELECT f.carrier, tailnum, airlines.name
FROM flights as f
JOIN airlines
ON f.carrier = airlines.carrier
""", con)
sql_result
# Out:
#        carrier tailnum                    name
# 0           UA  N14228   United Air Lines Inc.
# 1           UA  N24211   United Air Lines Inc.
# 2           AA  N619AA  American Airlines Inc.
# 3           B6  N804JB         JetBlue Airways
# 4           DL  N668DN    Delta Air Lines Inc.
# ...        ...     ...                     ...
# 336771      9E    None       Endeavor Air Inc.
# 336772      9E    None       Endeavor Air Inc.
# 336773      MQ  N535MQ               Envoy Air
# 336774      MQ  N511MQ               Envoy Air
# 336775      MQ  N839MQ               Envoy Air
#
# [336776 rows x 3 columns]

# %%
sql_result = pd.read_sql_query("""
SELECT *
FROM flights
LIMIT 10
""", con)
sql_result
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
# 5  2013      1    1     554.0             558       -4.0     740.0
# 6  2013      1    1     555.0             600       -5.0     913.0
# 7  2013      1    1     557.0             600       -3.0     709.0
# 8  2013      1    1     557.0             600       -3.0     838.0
# 9  2013      1    1     558.0             600       -2.0     753.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
# 5             728       12.0      UA    1696  N39463    EWR  ORD     150.0
# 6             854       19.0      B6     507  N516JB    EWR  FLL     158.0
# 7             723      -14.0      EV    5708  N829AS    LGA  IAD      53.0
# 8             846       -8.0      B6      79  N593JB    JFK  MCO     140.0
# 9             745        8.0      AA     301  N3ALAA    LGA  ORD     138.0
#
#    distance  hour  minute            time_hour
# 0      1400     5      15  2013-01-01 05:00:00
# 1      1416     5      29  2013-01-01 05:00:00
# 2      1089     5      40  2013-01-01 05:00:00
# 3      1576     5      45  2013-01-01 05:00:00
# 4       762     6       0  2013-01-01 06:00:00
# 5       719     5      58  2013-01-01 05:00:00
# 6      1065     6       0  2013-01-01 06:00:00
# 7       229     6       0  2013-01-01 06:00:00
# 8       944     6       0  2013-01-01 06:00:00
# 9       733     6       0  2013-01-01 06:00:00

# %%
# LEFT JOIN powoduje braki danych, czyli None w Carrier i tailnum
sql_result = pd.read_sql_query("""
SELECT pierwsze.carrier, pierwsze.tailnum, airlines.name
FROM airlines
LEFT JOIN (SELECT *
FROM flights
LIMIT 10) pierwsze
ON pierwsze.carrier = airlines.carrier
""", con)
sql_result
# Out:
#    carrier tailnum                         name
# 0     None    None            Endeavor Air Inc.
# 1       AA  N3ALAA       American Airlines Inc.
# 2       AA  N619AA       American Airlines Inc.
# 3     None    None         Alaska Airlines Inc.
# 4       B6  N516JB              JetBlue Airways
# 5       B6  N593JB              JetBlue Airways
# 6       B6  N804JB              JetBlue Airways
# 7       DL  N668DN         Delta Air Lines Inc.
# 8       EV  N829AS     ExpressJet Airlines Inc.
# 9     None    None       Frontier Airlines Inc.
# 10    None    None  AirTran Airways Corporation
# 11    None    None       Hawaiian Airlines Inc.
# 12    None    None                    Envoy Air
# 13    None    None        SkyWest Airlines Inc.
# 14      UA  N14228        United Air Lines Inc.
# 15      UA  N24211        United Air Lines Inc.
# 16      UA  N39463        United Air Lines Inc.
# 17    None    None              US Airways Inc.
# 18    None    None               Virgin America
# 19    None    None       Southwest Airlines Co.
# 20    None    None           Mesa Airlines Inc.
